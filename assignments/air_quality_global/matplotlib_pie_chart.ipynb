# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
df_patients=pd.read_csv(r'C:\Users\DELL\Coding\aiml_training\Day-10\patients.csv')
#df_patients

# %%
products=['Handphone','Laptop','Keyboard','Headphones']
weekly_sales=[400,200,600,150]
plt.figure(figsize=(10,10))
pie_colors=['blue','red','green','yellow']
plt.pie(weekly_sales, labels=products,colors=pie_colors)
plt.title('Weekly Products Sales Report')
#plt.xlabel('')
#plt.ylabel('Sales')
plt.show()

# %%
print(df_patients.head())
# Out:
#      patient_id               name  age arrival_date departure_date  \
# 0  PAT-09484753  Richard Rodriguez   24   2025-03-16     2025-03-22
# 1  PAT-f0644084     Shannon Walker    6   2025-12-13     2025-12-14
# 2  PAT-ac6162e4       Julia Torres   24   2025-06-29     2025-07-05
# 3  PAT-3dda2bb5    Crystal Johnson   32   2025-10-12     2025-10-23
# 4  PAT-08591375        Garrett Lin   25   2025-02-18     2025-02-25
#
#             service  satisfaction
# 0           surgery            61
# 1           surgery            83
# 2  general_medicine            83
# 3         emergency            81
# 4               ICU            76

# %%
service_counts=df_patients['service'].value_counts()
print(service_counts)
# Out:
# service
# emergency           263
# surgery             254
# general_medicine    242
# ICU                 241
# Name: count, dtype: int64

# %%
service_name=service_counts.index
print(service_name)
# Out:
# Index(['emergency', 'surgery', 'general_medicine', 'ICU'], dtype='object', name='service')

# %%
plt.pie(service_counts, labels=service_name,shadow=None)
plt.title(ditribution of patients by service', fontsize=20,fontweight='bold'.explode[0.5]*(service_counts)
# patients by service', fontsize=20,fontweight='bold'.explode[0.5]*(service_counts)
# Out:
#   Cell In[23], line 2
#     plt.title(ditribution of patients by service', fontsize=20,fontweight='bold'.explode[0.5]*(service_counts)
#                                                                                ^
# SyntaxError: unterminated string literal (detected at line 2)

# %%
players=['Danial','Qaisara','Raif','Adam','Luqman','Arika']
match1=[13,60,35,20,40,50]
match2=[40,15,23,50,58,30]
match3=[30,20,44,10,30,60]
plt.figure(figsize=(10,10))
plt.scatter(players,match1,color='red',label='Match One', s=100)
plt.scatter(players,match2,color='blue',label='Match Two', s=100, marker='d')
plt.scatter(players,match3,color='yellow',label='Match Three', s=100, marker='p')
plt.xlabel('Players')
plt.ylabel('Score')
plt.legend(loc='upper left')

plt.grid(True,linestyle='--',alpha=0.5)
plt.show()
